# %%
# importing necessary libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Loading the database 
df=pd.read_csv("SpaceServer.csv")
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# ...

# %%
#Changing the position of Column "class" to last position 
column_names = ['objid','ra','dec','u','g','r','i','z','run','rerun','camcol','field','specobjid','redshift','plate','mjd','fiberid','class']
df = df.reindex(columns=column_names)
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid  redshift  \
# ...

# %% [markdown]
# # Data Description

# %%
# 1) Object Identifier
# 2) Ra = J2000 Right Ascension (r-band)
# 3) Dec = J2000 Declination (r-band)
# 4) U = better of DeV/Exp magnitude fit
# 5) G = better of DeV/Exp magnitude fit
# 6) R = better of DeV/Exp magnitude fit
# 7) I = better of DeV/Exp magnitude fit
# 8) Z = better of DeV/Exp magnitude fit
# 9) Run Number
# 10) Rerun Number
# 11) Camera column
# 12) Field number
# 13) Object Identifier
# 14) Final Redshift
# 15) Plate Number
# 16) mjd = MJD of observation
# 17) Fiber ID
# 18) Class = object class (galaxy, star or quasar object)

# %%
#Renaming Column Names
df.columns=["Object Identifier","Ra", "Dec",  "U" ,"G" ,"R" , "I" ,"Z" ,"Run Number" ,"Rerun Number","Camera column","Field number" ,"Object Identifier","Final Redshift","Plate Numbe","MJD","Fiber ID","Class"]
df
# Out:
#       Object Identifier          Ra        Dec         U         G         R  \
# 0          1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1          1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2          1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3          1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4          1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...                 ...         ...        ...       ...       ...       ...
# 9995       1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996       1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997       1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998       1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999       1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
# ...

# %%
# Name of the columns
df.columns
# Out:
# Index(['Object Identifier', 'Ra', 'Dec', 'U', 'G', 'R', 'I', 'Z', 'Run Number',
#        'Rerun Number', 'Camera column', 'Field number', 'Object Identifier',
#        'Final Redshift', 'Plate Numbe', 'MJD', 'Fiber ID', 'Class'],
#       dtype='object')

# %%
# Shape of the database 
df.shape
# Out:
# (10000, 18)

# %%
#information of the database
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Object Identifier  10000 non-null  float64
#  1   Ra                 10000 non-null  float64
#  2   Dec                10000 non-null  float64
#  3   U                  10000 non-null  float64
#  4   G                  10000 non-null  float64
#  5   R                  10000 non-null  float64
#  6   I                  10000 non-null  float64
#  7   Z                  10000 non-null  float64
#  8   Run Number         10000 non-null  int64
#  9   Rerun Number       10000 non-null  int64
#  10  Camera column      10000 non-null  int64
#  11  Field number       10000 non-null  int64
#  12  Object Identifier  10000 non-null  float64
#  13  Final Redshift     10000 non-null  float64
#  14  Plate Numbe        10000 non-null  int64
#  15  MJD                10000 non-null  int64
# ...

# %%
#datatypes
df.dtypes
# Out:
# Object Identifier    float64
# Ra                   float64
# Dec                  float64
# U                    float64
# G                    float64
# R                    float64
# I                    float64
# Z                    float64
# Run Number             int64
# Rerun Number           int64
# Camera column          int64
# Field number           int64
# Object Identifier    float64
# Final Redshift       float64
# Plate Numbe            int64
# MJD                    int64
# Fiber ID               int64
# Class                 object
# dtype: object

# %%
df.describe()
# Out:
#        Object Identifier            Ra           Dec             U  \
# count       1.000000e+04  10000.000000  10000.000000  10000.000000
# mean        1.237650e+18    175.529987     14.836148     18.619355
# std         1.577039e+05     47.783439     25.212207      0.828656
# min         1.237650e+18      8.235100     -5.382632     12.988970
# 25%         1.237650e+18    157.370946     -0.539035     18.178035
# 50%         1.237650e+18    180.394514      0.404166     18.853095
# 75%         1.237650e+18    201.547279     35.649397     19.259232
# max         1.237650e+18    260.884382     68.542265     19.599900
#
#                   G             R             I             Z    Run Number  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      17.371931     16.840963     16.583579     16.422833    981.034800
# std        0.945457      1.067764      1.141805      1.203188    273.305024
# ...

# %%
# Making Heatmap of describe
plt.figure(figsize=(8,6))
sns.heatmap(df.describe())

# %%
#Finding Correlation of the variables
df.corr()
# Out:
#                    Object Identifier            Ra           Dec  \
# Object Identifier       1.000000e+00  2.524419e-14 -1.937483e-15
# Ra                      2.524419e-14  1.000000e+00  3.596046e-03
# Dec                    -1.937483e-15  3.596046e-03  1.000000e+00
# U                       5.581214e-14  3.123756e-02  3.527932e-02
# G                       1.001149e-13  4.390863e-02  6.187471e-02
# R                       2.995673e-14  4.710290e-02  6.340395e-02
# I                       2.212198e-14  4.573107e-02  5.829189e-02
# Z                      -4.107700e-14  4.294957e-02  5.687030e-02
# Run Number             -1.553011e-14 -9.274056e-02  7.783849e-01
# Rerun Number                     NaN           NaN           NaN
# Camera column           1.921887e-15 -6.293831e-03  1.146139e-01
# Field number            5.938881e-16  5.946996e-01 -1.314714e-01
# Object Identifier      -1.829075e-15 -9.532711e-02  8.834533e-02
# ...

# %%
# Making Heatmap of correlation
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)

# %%
#Finding Null values in database
df.isnull().sum()
# Out:
# Object Identifier    0
# Ra                   0
# Dec                  0
# U                    0
# G                    0
# R                    0
# I                    0
# Z                    0
# Run Number           0
# Rerun Number         0
# Camera column        0
# Field number         0
# Object Identifier    0
# Final Redshift       0
# Plate Numbe          0
# MJD                  0
# Fiber ID             0
# Class                0
# dtype: int64

# %% [markdown]
# # Multivariate Analysis

# %%
# Making Histrogram of all variables
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DB89F22AC8>,
# ...
#       dtype=object)

# %%
# Making Boxplot of all variables 
df.plot(kind='box',subplots=True,layout=(4,5),figsize=(25,25))
# Out:
# Ra                    AxesSubplot(0.125,0.71587;0.133621x0.16413)
# Dec                AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# U                   AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# G                  AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# R                  AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# I                    AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Z                 AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Run Number         AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# Rerun Number      AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# Camera column     AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# Field number         AxesSubplot(0.125,0.321957;0.133621x0.16413)
# Final Redshift    AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# Plate Numbe        AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# MJD               AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# ...

# %%
# Making Pairplot
plt.figure(figsize=(20,20))
sns.pairplot(df)

# %% [markdown]
# # Bivariate Analysis

# %%
# Countplot of Class
plt.figure(figsize=(8,5))
pd =sns.countplot(x = "Class" ,data=df)
for p in pd.patches:
    pd.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=18,
                   xytext = (0, -30), 
                   textcoords = 'offset points')
plt.xlabel("Class", size=15)
plt.ylabel("Count" ,size=15)
# Description :- Galaxy has maximum count
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Univariate Analysis

# %%
#Distplot of G
plt.figure(figsize=(8,5))
sns.distplot(df["G"], bins=30 )
plt.xlabel("G", Size=15 )
plt.show()

# %%
#Distplot of Z
plt.figure(figsize=(8,5))
sns.distplot(df["Z"], bins=30 )
plt.xlabel("Z", Size=15 )
plt.show()

# %%
# Voilinplot of MJD column.
plt.violinplot(df["MJD"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1dba4667248>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1dba465bf48>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1dba4667c48>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1dba4667bc8>}

# %%
# Voilinplot of Z column.
plt.violinplot(df["Z"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1dba48b9bc8>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1dba48afd48>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1dba48b9e08>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1dba48b9e88>}

# %%
# Voilinplot of Fiber ID column.
plt.violinplot(df["Fiber ID"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1dba46cc1c8>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1dba46c0f48>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1dba46ccc08>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1dba46cc448>}

# %%
# Voilinplot of U column.
plt.violinplot(df["U"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1dba4732108>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1dba4726e48>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1dba4732b08>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1dba4732f88>}

# %%
# droping  column Object Identifier ,Rerun Number  from  dataset because they have same value in entire dataset.
df= df.drop(['Object Identifier','Rerun Number'],axis = 1)

# %%
#Using Label Encoder 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
list1=['Class']
for val in list1:
     df[val]=le.fit_transform(df[val].astype(str))

# %%
df
# Out:
#               Ra        Dec         U         G         R         I         Z  \
# 0     183.531326   0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1     183.598371   0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2     183.680207   0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3     183.870529   0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4     183.883288   0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
# ...          ...        ...       ...       ...       ...       ...       ...
# 9995  131.316413  51.539547  18.81777  17.47053  16.91508  16.68305  16.50570
# 9996  131.306083  51.671341  18.27255  17.43849  17.07692  16.71661  16.69897
# 9997  131.552562  51.666986  18.75818  17.77784  17.51872  17.43302  17.42048
# 9998  131.477151  51.753068  18.88287  17.91068  17.53152  17.36284  17.13988
# 9999  131.665012  51.805307  19.27586  17.37829  16.30542  15.83548  15.50588
#
# ...

# %% [markdown]
# # Splitting Data into target and Input

# %%
x=df.iloc[:,0:-1]
x
# Out:
#               Ra        Dec         U         G         R         I         Z  \
# 0     183.531326   0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1     183.598371   0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2     183.680207   0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3     183.870529   0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4     183.883288   0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
# ...          ...        ...       ...       ...       ...       ...       ...
# 9995  131.316413  51.539547  18.81777  17.47053  16.91508  16.68305  16.50570
# 9996  131.306083  51.671341  18.27255  17.43849  17.07692  16.71661  16.69897
# 9997  131.552562  51.666986  18.75818  17.77784  17.51872  17.43302  17.42048
# 9998  131.477151  51.753068  18.88287  17.91068  17.53152  17.36284  17.13988
# 9999  131.665012  51.805307  19.27586  17.37829  16.30542  15.83548  15.50588
#
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       2
# 1       2
# 2       0
# 3       2
# 4       2
#        ..
# 9995    0
# 9996    0
# 9997    2
# 9998    0
# 9999    0
# Name: Class, Length: 10000, dtype: int32

# %%
# standard scaling data 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
print(scaler.fit(x))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x
# Out:
#               Ra        Dec         U         G         R         I         Z  \
# 0     183.531326   0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1     183.598371   0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2     183.680207   0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3     183.870529   0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4     183.883288   0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
# ...          ...        ...       ...       ...       ...       ...       ...
# 9995  131.316413  51.539547  18.81777  17.47053  16.91508  16.68305  16.50570
# 9996  131.306083  51.671341  18.27255  17.43849  17.07692  16.71661  16.69897
# 9997  131.552562  51.666986  18.75818  17.77784  17.51872  17.43302  17.42048
# 9998  131.477151  51.753068  18.88287  17.91068  17.53152  17.36284  17.13988
# 9999  131.665012  51.805307  19.27586  17.37829  16.30542  15.83548  15.50588
#
# ...

# %% [markdown]
# # Importing Necessary libraries¶

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,roc_auc_score,roc_curve,auc
from sklearn.model_selection import GridSearchCV

# %%
max_acc_score=0
for i in range(42,101):
    r_state=i
    train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=r_state ,test_size=0.20)
    dtc=DecisionTreeClassifier()
    dtc.fit(train_x,train_y)
    pred=dtc.predict(test_x)
    acc_score=accuracy_score(test_y,pred)
    if acc_score> max_acc_score:
            max_acc_score=acc_score
            final_r_state=r_state
print("The max accuracy score  for DecisionTreeClassifier ", max_acc_score,"is achieved at" ,final_r_state)
print("\n")


max_acc_score=0
for i in range(42,101):
    r_state=i
    train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=r_state ,test_size=0.20)
    knn=KNeighborsClassifier()
    knn.fit(train_x,train_y)
    pred=knn.predict(test_x)
    acc_score=accuracy_score(test_y,pred)
    if acc_score> max_acc_score:
            max_acc_score=acc_score
            final_r_state=r_state
print("The max accuracy score  for KNeighborsClassifier", max_acc_score,"is achieved at" ,final_r_state)
print("\n")



max_acc_score=0
for i in range(42,101):
    r_state=i
    train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=r_state ,test_size=0.20)
    rfc=RandomForestClassifier()
    rfc.fit(train_x,train_y)
    pred=rfc.predict(test_x)
    acc_score=accuracy_score(test_y,pred)
    if acc_score> max_acc_score:
            max_acc_score=acc_score
            final_r_state=r_state
print("The max accuracy score  for RandomForestClassifier ", max_acc_score,"is achieved at" ,final_r_state)
print("\n")


max_acc_score=0
for i in range(42,101):
    r_state=i
    train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=r_state ,test_size=0.20)
    ada=AdaBoostClassifier()
    ada.fit(train_x,train_y)
    pred=ada.predict(test_x)
    acc_score=accuracy_score(test_y,pred)
    if acc_score> max_acc_score:
            max_acc_score=acc_score
            final_r_state=r_state
print("The max accuracy score  for AdaBoostClassifier", max_acc_score,"is achieved at" ,final_r_state)
print("\n")



max_acc_score=0
for i in range(42,101):
    r_state=i
    train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=r_state ,test_size=0.20)
    gbr=GradientBoostingClassifier()
    gbr.fit(train_x,train_y)
    pred=gbr.predict(test_x)
    acc_score=accuracy_score(test_y,pred)
    if acc_score> max_acc_score:
            max_acc_score=acc_score
            final_r_state=r_state
print("The max accuracy score  for GradientBoostingClassifier", max_acc_score,"is achieved at" ,final_r_state)
print("\n")
# Out:
# The max accuracy score  for DecisionTreeClassifier  0.9935 is achieved at 62
#
#
# The max accuracy score  for KNeighborsClassifier 0.8 is achieved at 73
#
#
# The max accuracy score  for RandomForestClassifier  0.994 is achieved at 59
#
#
# The max accuracy score  for AdaBoostClassifier 0.988 is achieved at 75
#
#
# The max accuracy score  for GradientBoostingClassifier 0.9945 is achieved at 45

# %%
#Best parameters for KNeighborsClassifier
knn=KNeighborsClassifier()
parameters={"n_neighbors" :(5,20) ,'algorithm' :('auto', 'ball_tree', 'kd_tree', 'brute')}
gd=GridSearchCV(knn,parameters)
gd.fit(train_x,train_y)
print(gd.best_params_)
print("\n")


#Best parameters for DecisionTreeClassifier
dtc=DecisionTreeClassifier()
parameters={"criterion" :("gini" ,"entropy") ,'max_features':('auto', 'sqrt', 'log2')}
gd=GridSearchCV(dtc,parameters)
gd.fit(train_x,train_y)
print(gd.best_params_)
print("\n")

#Best parameters for  RandomForestClassifier
rfc=RandomForestClassifier()
parameters={"criterion" :("gini" ,"entropy") ,'max_features':('auto', 'sqrt', 'log2')}
gd=GridSearchCV(rfc,parameters)
gd.fit(train_x,train_y)
print(gd.best_params_)
print("\n")


#Best parameters for  AdaboostClassifier 
ada=AdaBoostClassifier()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,50,100,150,200]}
gd=GridSearchCV(ada,parameters)
gd.fit(train_x,train_y)
print(gd.best_params_)
print("\n")
# Out:
# {'algorithm': 'auto', 'n_neighbors': 20}
#
#
# {'criterion': 'gini', 'max_features': 'sqrt'}
#
#
# {'criterion': 'gini', 'max_features': 'log2'}
#
#
# {'learning_rate': 0.1, 'n_estimators': 50}

# %%
model=[]
score=[]
cvs=[]
rocscore=[]


for i in [KNeighborsClassifier(n_neighbors=20 ,algorithm = 'auto'  ) ,
          DecisionTreeClassifier(criterion ="gini" , random_state= 62  ,max_features = 'sqrt'),
          RandomForestClassifier(criterion ="gini" , random_state= 59 ,max_features = 'log2' ),
          AdaBoostClassifier( learning_rate = 0.1, n_estimators = 50 ,random_state= 75 )]:
          
          
        k=i
        model.append(i)
        print("\n")
        print("The model calculation for" ,i,"are:" )
        k.fit(train_x,train_y)
        k.score(train_x,train_y)
        predict =k.predict(test_x)
        print(predict)
        AS=accuracy_score(predict,test_y)
        print("Accuracy Score= " ,AS)
        score.append(AS)
        cv_score=cross_val_score(k,x,y,cv=5,scoring="accuracy").mean()
        print("The CV Score is"  ,cv_score)
        cvs.append(cv_score)
        print("")
        cm=confusion_matrix(predict,test_y)
        print(cm)
        print("")
        print(classification_report(predict,test_y))
        print("\n")
# Out:
# The model calculation for KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=20, p=2,
#                      weights='uniform') are:
# [2 0 2 ... 2 0 2]
# Accuracy Score=  0.804
# The CV Score is 0.7751
#
# [[960 139 184]
#  [  0   5   3]
#  [ 39  27 643]]
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.75      0.84      1283
#            1       0.03      0.62      0.06         8
#            2       0.77      0.91      0.84       709
#
#     accuracy                           0.80      2000
#    macro avg       0.59      0.76      0.58      2000
# weighted avg       0.89      0.80      0.84      2000
#
#
#
#
#
# The model calculation for DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='sqrt', max_leaf_nodes=None,
# ...

# %% [markdown]
# # Since RandomForestClassifier is giving best result so we choose it as final model.

# %%
rfc=RandomForestClassifier(criterion ="gini" , random_state= 59 ,max_features = 'log2' )
rfc.fit(train_x,train_y)
predict=rfc.predict(test_x)
AS=accuracy_score(predict,test_y)
print("Accuracy Score=" ,AS)
cv_score=cross_val_score(rfc,x,y,cv=5,scoring="accuracy").mean()
print("The CV Score is", cv_score)
# Out:
# Accuracy Score= 0.9885
# The CV Score is 0.9888

# %% [markdown]
# # Saving the model

# %%
from sklearn.externals import joblib
joblib.dump(rfc,"spaceserver.pkl")
# Out:
# ['spaceserver.pkl']

# %% [markdown]
# # Saving Prediction in csv file

# %%
dft=pd.DataFrame(predict)
dft.to_csv("space6.csv")
