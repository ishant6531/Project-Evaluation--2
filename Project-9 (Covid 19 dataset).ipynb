# %%
# importing necessary libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Loading the database 
df=pd.read_csv("covid18.csv")
df
# Out:
#      Province_State Country_Region      Last_Update      Lat     Long_  \
# 0           Alabama             US  4/12/2020 23:18  32.3182  -86.9023
# 1            Alaska             US  4/12/2020 23:18  61.3707 -152.4044
# 2           Arizona             US  4/12/2020 23:18  33.7298 -111.4312
# 3          Arkansas             US  4/12/2020 23:18  34.9697  -92.3731
# 4        California             US  4/12/2020 23:18  36.1162 -119.6816
# ...             ...            ...              ...      ...       ...
# 8291       Virginia             US    9/3/2020 4:30  37.7693  -78.1700
# 8292     Washington             US    9/3/2020 4:30  47.4009 -121.4905
# 8293  West Virginia             US    9/3/2020 4:30  38.4912  -80.9545
# 8294      Wisconsin             US    9/3/2020 4:30  44.2685  -89.6165
# 8295        Wyoming             US    9/3/2020 4:30  42.7560 -107.3025
#
#       Confirmed  Deaths  Recovered    Active  FIPS  Incident_Rate  \
# ...

# %% [markdown]
# # Data Description

# %%
# Province_State - The name of the State within the USA.
# Country_Region - The name of the Country (US).
# Last_Update - The most recent date the file was pushed.
# Lat - Latitude.
# Long_ - Longitude.
# Confirmed - Aggregated confirmed case count for the state.
# Deaths - Aggregated Death case count for the state.
# Recovered - Aggregated Recovered case count for the state.
# Active - Aggregated confirmed cases that have not been resolved (Active = Confirmed - Recovered - Deaths).
# FIPS - Federal Information Processing Standards code that uniquely identifies counties within the USA.
# Incident_Rate - confirmed cases per 100,000 persons.
# People_Tested - Total number of people who have been tested.
# People_Hospitalized - Total number of people hospitalized.
# Mortality_Rate - Number recorded deaths * 100/ Number confirmed cases.
# UID - Unique Identifier for each row entry.
# ISO3 - Officialy assigned country code identifiers.
# Testing_Rate - Total number of people tested per 100,000 persons.
# Hospitalization_Rate - Total number of people hospitalized * 100/ Number of confirmed cases.

# %%
# Name of the columns
df.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3',
#        'Testing_Rate', 'Hospitalization_Rate'],
#       dtype='object')

# %%
# Shape of the database 
df.shape
# Out:
# (8296, 18)

# %%
#information of the database
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8296 entries, 0 to 8295
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        8294 non-null   object
#  1   Country_Region        8294 non-null   object
#  2   Last_Update           8284 non-null   object
#  3   Lat                   8008 non-null   float64
#  4   Long_                 8008 non-null   float64
#  5   Confirmed             8294 non-null   float64
#  6   Deaths                8294 non-null   float64
#  7   Recovered             6443 non-null   float64
#  8   Active                8277 non-null   float64
#  9   FIPS                  8293 non-null   float64
#  10  Incident_Rate         8008 non-null   float64
#  11  People_Tested         8008 non-null   float64
#  12  People_Hospitalized   5096 non-null   float64
#  13  Mortality_Rate        8151 non-null   float64
# ...

# %%
#datatypes
df.dtypes
# Out:
# Province_State           object
# Country_Region           object
# Last_Update              object
# Lat                     float64
# Long_                   float64
# Confirmed               float64
# Deaths                  float64
# Recovered               float64
# Active                  float64
# FIPS                    float64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                     float64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %%
df.describe()
# Out:
#                Lat        Long_      Confirmed        Deaths      Recovered  \
# count  8008.000000  8008.000000    8294.000000   8294.000000    6443.000000
# mean     36.840089   -85.206614   49910.531107   2035.452375   19033.945833
# std      10.790066    49.311291   91825.812656   4491.498531   38958.514524
# min     -14.271000  -170.132200       0.000000      0.000000       0.000000
# 25%      34.594600  -101.165775    3397.500000     85.000000    1137.000000
# 50%      39.061850   -87.944200   16625.500000    489.000000    5019.000000
# 75%      42.361650   -76.970625   54197.500000   1874.750000   23197.000000
# max      61.370700   145.673900  721281.000000  32972.000000  522087.000000
#
#               Active          FIPS  Incident_Rate  People_Tested  \
# count    8277.000000   8293.000000    8008.000000   8.008000e+03
# mean    33316.665821   3265.924153     719.352231   5.929587e+05
# std     75881.158215  17201.321656     646.538053   1.107527e+06
# ...

# %%
# Making Heatmap of describe
plt.figure(figsize=(8,6))
sns.heatmap(df.describe())

# %%
#Finding Correlation of the variables
df.corr()
# Out:
#                            Lat     Long_  Confirmed    Deaths  Recovered  \
# Lat                   1.000000 -0.278274   0.024255  0.104216  -0.026371
# Long_                -0.278274  1.000000  -0.042766  0.015173  -0.049929
# Confirmed             0.024255 -0.042766   1.000000  0.769394   0.777506
# Deaths                0.104216  0.015173   0.769394  1.000000   0.422906
# Recovered            -0.026371 -0.049929   0.777506  0.422906   1.000000
# Active                0.004133 -0.044799   0.918688  0.692799   0.390047
# FIPS                 -0.374632  0.367924  -0.102205 -0.085245  -0.040386
# Incident_Rate         0.145500 -0.041858   0.618030  0.528363   0.466935
# People_Tested         0.045877 -0.064854   0.909303  0.685607   0.698146
# People_Hospitalized   0.020735  0.116809   0.872122  0.964679   0.558231
# Mortality_Rate       -0.054258  0.285349   0.082420  0.344246   0.026833
# UID                   0.774106 -0.526908   0.159429  0.136468   0.130144
# ...

# %%
# Making Heatmap of correlation
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)

# %%
#Finding Null values in database
df.isnull().sum()
# Out:
# Province_State             2
# Country_Region             2
# Last_Update               12
# Lat                      288
# Long_                    288
# Confirmed                  2
# Deaths                     2
# Recovered               1853
# Active                    19
# FIPS                       3
# Incident_Rate            288
# People_Tested            288
# People_Hospitalized     3200
# Mortality_Rate           145
# UID                        2
# ISO3                       2
# Testing_Rate             288
# Hospitalization_Rate    3201
# dtype: int64

# %% [markdown]
# # Bivariate Analysis

# %%
# Barplot of Confirmed Covid  Cases in Different Province State.
plt.figure(figsize=(30,15))
pd =sns.barplot(x = "Province_State", y = "Confirmed",  data=df )
plt.xticks(rotation= 90)
plt.xlabel("Province State" , size=25)
plt.ylabel("Confirmed Cases" ,size=25)
plt.title (" Total Number Of Confirmed Covid Cases in Different Province State" , size=25)
plt.show()
# Conclusion :- NewYork has maximum confirmed covid cases.

# %%
# Barplot of Deaths in Different Province State.
plt.figure(figsize=(30,15))
pd =sns.barplot(x = "Province_State", y = "Deaths",  data=df)
plt.xticks(rotation= 90)
plt.xlabel("Province State" , size=25)
plt.ylabel("Deaths " ,size=25)
plt.title (" Total Number Of Deaths  due to covid in Different Province State" , size=25)
plt.show()
# Conclusion :- NewYork has maximum Deaths due to covid.

# %%
# Barplot of Recovered cases in Different Province State.
plt.figure(figsize=(30,15))
pd =sns.barplot(x = "Province_State", y = "Recovered",  data=df )
plt.xticks(rotation= 90)
plt.xlabel("Province State" , size=25)
plt.ylabel("Recovered Cases" ,size=25)
plt.title (" Total Number Of Recovered cases  in Different Province State" , size=25)
plt.show()
#Conclusion :- Texas  has maximum Recovered cases .

# %%
# Barplot of Mortality Rate  in Different Province State.
plt.figure(figsize=(30,15))
pd =sns.barplot(x = "Province_State", y = "Mortality_Rate",  data=df )
plt.xticks(rotation= 90)
plt.xlabel("Province State" , size=25)
plt.ylabel("Mortality Rate" ,size=25)
plt.title (" Total Number Of Mortality Rate  in Different Province State" , size=25)
plt.show()
#Conclusion :- Northeren Mariana  island   has maximum Mortality cases .

# %%
# Barplot of Active Cases  in Different Province State.
plt.figure(figsize=(30,15))
pd =sns.barplot(x = "Province_State", y = "Active",  data=df)
plt.xticks(rotation= 90)
plt.xlabel("Province State" , size=25)
plt.ylabel("Active Cases " ,size=25)
plt.title (" Total Number Of Active Covid  Cases   in Different Province State" , size=25)
plt.show()
#Conclusion :- New York  has maximum active cases of covid  .

# %%
# Barplot of People Tested for covid in Different Province State.
plt.figure(figsize=(30,15))
pd =sns.barplot(x = "Province_State", y = "People_Tested",  data=df )
plt.xticks(rotation= 90)
plt.xlabel("Province State" , size=25)
plt.ylabel("People Tested" ,size=25)
plt.title (" Total Number Of People Tested for  Covid in Different Province State" , size=25)
plt.show()
#Conclusion :- California   has maximum people tested for covid.

# %%
# Barplot of Hospitalization Rate in Different Province State.
plt.figure(figsize=(30,15))
pd =sns.barplot(x = "Province_State", y = "Hospitalization_Rate",  data=df )
plt.xticks(rotation= 90)
plt.xlabel("Province State" , size=25)
plt.ylabel("Hospitalization Rate" ,size=25)
plt.title (" Hospitalization Rate in Different Province State" , size=25)
plt.show()
#Conclusion :- Connecticut has maximum people hospitalized.

# %%
# Barplot of Testing Rate in Different Province State.
plt.figure(figsize=(30,15))
pd =sns.barplot(x = "Province_State", y = "Testing_Rate",  data=df )
plt.xticks(rotation= 90)
plt.xlabel("Province State" , size=25)
plt.ylabel("Testing Rate" ,size=25)
plt.title ("Testing Rate in Different Province State" , size=25)
plt.show()
# #Conclusion :- NewYork  has maximum testing rate as compared to different province state.

# %% [markdown]
# # Multivariate analysis

# %%
#Making pairplot
sns.pairplot(df)

# %%
# Making Boxplot of all variables
df.plot(kind='box',subplots=True,layout=(7,5),figsize=(25,25))
# Out:
# Lat                        AxesSubplot(0.125,0.787927;0.133621x0.0920732)
# Long_                   AxesSubplot(0.285345,0.787927;0.133621x0.0920732)
# Confirmed                AxesSubplot(0.44569,0.787927;0.133621x0.0920732)
# Deaths                  AxesSubplot(0.606034,0.787927;0.133621x0.0920732)
# Recovered               AxesSubplot(0.766379,0.787927;0.133621x0.0920732)
# Active                     AxesSubplot(0.125,0.677439;0.133621x0.0920732)
# FIPS                    AxesSubplot(0.285345,0.677439;0.133621x0.0920732)
# Incident_Rate            AxesSubplot(0.44569,0.677439;0.133621x0.0920732)
# People_Tested           AxesSubplot(0.606034,0.677439;0.133621x0.0920732)
# People_Hospitalized     AxesSubplot(0.766379,0.677439;0.133621x0.0920732)
# Mortality_Rate             AxesSubplot(0.125,0.566951;0.133621x0.0920732)
# UID                     AxesSubplot(0.285345,0.566951;0.133621x0.0920732)
# Testing_Rate             AxesSubplot(0.44569,0.566951;0.133621x0.0920732)
# ...

# %%
# Making Histrogram of all variables
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BD1AB553C8>,
# ...
#       dtype=object)

# %%
# droping  column Last_Update, Lat, Long_  from  dataset
df= df.drop(['Last_Update', 'Lat', 'Long_' ,'Country_Region'],axis = 1)

# %%
# Droping Null values in Test Dataset
df=df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# Province_State          0
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# FIPS                    0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# UID                     0
# ISO3                    0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %%
#Using Label Encoder 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
list1=['Province_State','ISO3','UID']
for val in list1:
     df[val]=le.fit_transform(df[val].astype(str))

# %%
df.isnull().sum()
# Out:
# Province_State          0
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# FIPS                    0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# UID                     0
# ISO3                    0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %%
df=df.round(decimals=2)

# %%
# Calculating zscore 
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.78702524, 0.57440736, 0.38234341, ..., 0.11823764, 1.13618734,
#         0.08514661],
#        [1.63185253, 0.56042254, 0.37892362, ..., 0.11823764, 1.21596778,
#         0.32390278],
#        [1.39909346, 0.55563606, 0.3774837 , ..., 0.11823764, 1.16417399,
#         0.02930847],
#        ...,
#        [1.39401535, 1.03907835, 0.07104977, ..., 0.11823764, 1.09689722,
#         0.35193122],
#        [1.54918806, 0.4365237 , 0.18381516, ..., 0.11823764, 1.56261978,
#         0.78408605],
#        [1.62677442, 0.52639001, 0.37712372, ..., 0.11823764, 0.44217648,
#         1.1711021 ]])

# %%
# removing outliners
df=df[(z<3).all(axis=1)]

# %% [markdown]
# # Splitting Data into target and Input

# %%
x=df.iloc[:,0:-1]
x
# Out:
#       Province_State  Confirmed  Deaths  Recovered   Active  FIPS  \
# 1                  1      272.0     8.0       66.0    264.0   2.0
# 3                  3     1280.0    27.0      367.0   1253.0   5.0
# 7                  6     1625.0    35.0      191.0   1590.0  10.0
# 14                11      499.0     9.0      300.0    490.0  15.0
# 18                14     1587.0    41.0      674.0   1546.0  19.0
# ...              ...        ...     ...        ...      ...   ...
# 7937              37    12194.0   162.0    10032.0   2000.0  46.0
# 7940              40    50557.0   403.0    42512.0   7642.0  49.0
# 7943              42   116569.0  2527.0    14764.0  99278.0  51.0
# 7946              44    73138.0  1111.0    64480.0   7547.0  55.0
# 7947              45     3733.0    37.0     3060.0    636.0  56.0
#
#       Incident_Rate  People_Tested  People_Hospitalized  Mortality_Rate  UID  \
# 1             45.50         8038.0                 31.0            2.94    3
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 1       11.40
# 3       10.16
# 7       11.69
# 14       8.82
# 18       8.13
#         ...
# 7937     8.06
# 7940     5.96
# 7943    13.67
# 7946     7.77
# 7947     5.76
# Name: Hospitalization_Rate, Length: 3890, dtype: float64

# %%
# standard scaling data 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
print(scaler.fit(x))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# # Importing Necessary libraries

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import LinearRegression

# %%
def maxr2_score(regr,x,y):
    max_r_score=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state= i ,test_size=0.20)
        regr.fit(x,y)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_i=i
    print(" We are getting maximum  r2 score corresponding to",final_i,"is",max_r_score)
    return final_i

# %%
# using Grid search CV to find best  parameters of different algorithim .
knn=KNeighborsRegressor()
parameters={"n_neighbors" :(5,20) , 'algorithm' :['auto', 'ball_tree', 'kd_tree', 'brute']}
gd=GridSearchCV(knn,parameters)
gd.fit(x,y)
print(" Best parameters of KNeighborsRegressor is :-")
print(gd.best_params_)
print("\n")

lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1] , 'selection' : ['cyclic', 'random']}
gd=GridSearchCV(lsreg,parameters)
gd.fit(x,y)
print(" Best parameters of Lasso is :-")
print(gd.best_params_)
print("\n")

dtc=DecisionTreeRegressor()
parameters={"criterion" :( 'mse', 'friedman_mse', 'mae') ,'max_features' : ['auto', 'sqrt', 'log2']}
gd=GridSearchCV(dtc,parameters)
gd.fit(x,y)
print(" Best parameters of DecisionTreeRegressor is :-")
print(gd.best_params_)
print("\n")

#Best parameters for RandomForestRegressor
rfr=RandomForestRegressor()
parameters={"criterion" :('mse', 'mae') , 'max_features' : ['auto', 'sqrt', 'log2']}
gd=GridSearchCV(rfr,parameters)
gd.fit(x,y)
print(" Best parameters of RandomForestRegressor is :-")
print(gd.best_params_)
print("\n")

#Best parameters for  AdaBoostRegressor
ada=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[25,50,100,150,200]}
gd=GridSearchCV(ada,parameters)
gd.fit(x,y)
print(" Best parameters of AdaBoostRegressor is :-")
print(gd.best_params_)
print("\n")
# Out:
#  Best parameters of KNeighborsRegressor is :-
# {'algorithm': 'auto', 'n_neighbors': 20}
#
#
#  Best parameters of Lasso is :-
# {'alpha': 0.1, 'selection': 'random'}
#
#
#  Best parameters of DecisionTreeRegressor is :-
# {'criterion': 'friedman_mse', 'max_features': 'auto'}
#
#
#  Best parameters of RandomForestRegressor is :-
# {'criterion': 'mae', 'max_features': 'log2'}
#
#
#  Best parameters of AdaBoostRegressor is :-
# {'learning_rate': 1, 'n_estimators': 150}

# %%
# Finding best r2 score value for Linear Regression 
print("Linear Regression")
print("................. ")
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
print(" ")
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Linear Regression:",cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
print(" ")
print("#############################################################################")
print(" ")


# Finding best r2 score value for KNeighbors regressor 
print("KNeighbors regressor ")
print("..................... ")
knn=KNeighborsRegressor(n_neighbors= 20 , algorithm = 'auto')
i=maxr2_score(knn,x,y)
print(" ")
from sklearn.model_selection import cross_val_score
print("Mean r2 score for KNeighbor  Regression:",cross_val_score(knn,x,y,cv=135,scoring="r2").mean())
print("standard deviation in r2 score for KNeighbor   Regression",cross_val_score(knn,x,y,cv=5,scoring="r2").std())
print(" ")
print("##############################################################################")
print(" ")


# Finding best r2 score value for Lasso Regressor 
print("Lasso Regressor")
print("................ ")
lsreg=Lasso(alpha=0.1 , selection = 'random')
i=maxr2_score(lsreg,x,y)
print(" ")
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=63,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression",cross_val_score(lsreg,x,y,cv=5,scoring="r2").std())
print(" ")
print("################################################################################")
print(" ")

# Finding best r2 score value for DecisionTreeRegressor
print("DecisionTreeRegressor")
print("...................... ")
dtc=DecisionTreeRegressor(criterion = 'friedman_mse'  , max_features = 'auto')
i=maxr2_score(dtc,x,y)
print(" ")
from sklearn.model_selection import cross_val_score
print("Mean r2 score for DecisionTreeRegressor :",cross_val_score(dtc,x,y,cv=139,scoring="r2").mean())
print("standard deviation in r2 score for DecisionTreeRegressor",cross_val_score(dtc,x,y,cv=5,scoring="r2").std())
print(" ")
print("#################################################################################")
print(" ")

# Finding best r2 score value for  RandomForestRegressor
print("RandomForestRegressor")
print("..................... ")
rfr=RandomForestRegressor(criterion = 'mae'  , max_features = 'log2')
i=maxr2_score(rfr,x,y)
print(" ")
print("Mean r2 score for RandomForestRegressor :",cross_val_score(rfr,x,y,cv=10,scoring="r2").mean())
print("standard deviation in r2 score for RandomForestRegressor ",cross_val_score(rfr,x,y,cv=5,scoring="r2").std())
print(" ")
print("##################################################################################")
print(" ")


# Finding best r2 score value for  AdaBoostRegressor
print("AdaBoostRegressor")
print(".................. ")
ada=AdaBoostRegressor(n_estimators=150 , learning_rate = 1)
i=maxr2_score(ada,x,y)
print(" ")
print("Mean r2 score for AdaBoostRegressor :",cross_val_score(ada,x,y,cv=10,scoring="r2").mean())
print("standard deviation in r2 score for AdaBoostRegressor ",cross_val_score(ada,x,y,cv=5,scoring="r2").std())
print(" ")
print("#####################################################################################")
# Out:
# Linear Regression
# .................
#  We are getting maximum  r2 score corresponding to 85 is 0.7596335255501825
#
# Mean r2 score for Linear Regression: 0.6088961945538431
# standard deviation in r2 score for Linear Regression 0.15228608447656636
#
# #############################################################################
#
# KNeighbors regressor
# .....................
#  We are getting maximum  r2 score corresponding to 43 is 0.5527211840085635
#
# Mean r2 score for KNeighbor  Regression: 0.32597202366372274
# standard deviation in r2 score for KNeighbor   Regression 0.240988632275931
#
# ##############################################################################
#
# Lasso Regressor
# ................
#  We are getting maximum  r2 score corresponding to 85 is 0.7509562200939605
#
# Mean r2 score for Lasso Regression: 0.6868303032453176
# standard deviation in r2 score for Lasso Regression 0.13397078241883206
#
# ...

# %% [markdown]
# # Since Decision Tree Regressor  is giving better result so we will use it as final model.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.20)
dtc=DecisionTreeRegressor(criterion = 'friedman_mse'  , max_features = 'auto')
dtc.fit(x,y)
y_pred=dtc.predict(x_test)

# %%
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is:",r2_score(y_test,y_pred))
print("cross value score :",cross_val_score(dtc,x,y,cv=139,scoring="r2").mean())
# Out:
# RMSE is:  1.5599692554030053e-16
# r2_score is: 1.0
# cross value score : 0.9697360012955509

# %% [markdown]
# # Saving the model

# %%
from sklearn.externals import joblib
joblib.dump(dtc,"covid_US.pkl")
# Out:
# ['covid_US.pkl']
